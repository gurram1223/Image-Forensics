# %%
import numpy as np
import pandas as pd
import seaborn as sns
import os
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
from PIL import Image
Image.LOAD_TRUNCATED_IMAGES = True
from imageio import imread
from datetime import datetime
import shutil
import skimage
import cv2
import pickle
from sklearn.model_selection import train_test_split
from sklearn.metrics import log_loss, accuracy_score, confusion_matrix

from __future__ import print_function
import keras
from keras import applications
from keras.models import Sequential
from keras.layers import Conv2D,Conv2DTranspose,MaxPooling2D
from keras import backend as K
from keras.layers import Dropout, Flatten, Dense, GlobalAveragePooling2D,BatchNormalization
from keras.initializers import RandomNormal
from keras.initializers import he_normal
from keras.applications import vgg16 as vgg
from keras.applications.resnet50 import ResNet50
from keras.optimizers import adam
from keras import optimizers
from keras.models import Model, load_model
from keras.layers import Input, BatchNormalization, Activation, Dense, Dropout
from keras.layers.core import Lambda, RepeatVector, Reshape
from keras.layers.merge import concatenate, add
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img

import warnings
warnings.filterwarnings("ignore")
# Out:
# C:\Users\Administrator\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
fake_path  = "C:/Users/Administrator/Documents/Datasets/Image Forensic Challenge/phase-01-training/dataset-dist/phase-01/training/fake/fake_128/"
fake_file_names = os.listdir(fake_path)

# %%
start = datetime.now()
    
fcount = 0 

if not os.path.isdir(fake_path+'fake_grey_128/'):
    os.mkdir(fake_path+'fake_grey_128/')
for file in fake_file_names:
    if len(file.split('.')) == 2:
        img = Image.open(fake_path+file)
        if img.mode != 'L':
            img = img.convert('L')           
            # Printing after conversion
            print("Shape : ", img.size, "Mode : ",img.mode,"file : ", file)
            
            img.save(fake_path+'fake_grey_128/'+file)
    
            
print("Time taken to run this cell :", datetime.now() - start)
# Out:
# Shape :  (128, 128) Mode :  L file :  010543abfbd0db1e9aa1b24604336e0c.png
# Shape :  (128, 128) Mode :  L file :  022354380a1a17ff49226c9eae21a11f.png
# Shape :  (128, 128) Mode :  L file :  0294345b3b2324b195cb3b30e91d7678.png
# Shape :  (128, 128) Mode :  L file :  0363353570f16ff0a73aa0a03a7795b8.png
# Shape :  (128, 128) Mode :  L file :  0830004e471e511458600f0763ce19f3.png
# Shape :  (128, 128) Mode :  L file :  08829849d0b1c71e437961e841e0c81f.png
# Shape :  (128, 128) Mode :  L file :  0908dafde12041540b70d688315df6e9.png
# Shape :  (128, 128) Mode :  L file :  092b43f88eab0ae3ecc0eb0ccbe37c82.png
# Shape :  (128, 128) Mode :  L file :  12362143f7e114beeb9d22dc59450f5a.png
# Shape :  (128, 128) Mode :  L file :  14548214e97adf237ee3bac90809baf6.png
# Shape :  (128, 128) Mode :  L file :  152681a0017a5fded699c43cd6df97d1.png
# Shape :  (128, 128) Mode :  L file :  17030938cc2cb314cb87552dcc9516a4.png
# Shape :  (128, 128) Mode :  L file :  1848de26a06a7831457609429c92e2e7.png
# Shape :  (128, 128) Mode :  L file :  1990a2ed067b8c537d8fe36d1ab4a7f2.png
# Shape :  (128, 128) Mode :  L file :  207763f02c2c5881c898386782da1728.png
# Shape :  (128, 128) Mode :  L file :  2170480823e668068b78bce75afe07a1.png
# Shape :  (128, 128) Mode :  L file :  229f447c1a26a74005b3f058201bde3f.png
# Shape :  (128, 128) Mode :  L file :  2377136d0e2ec5c8aa15293c78ffa3d7.png
# Shape :  (128, 128) Mode :  L file :  237db9303fe590d8104510e36dfaa4a7.png
# Shape :  (128, 128) Mode :  L file :  244a7433a307b9a2c839cefe14c0ba1d.png
# Shape :  (128, 128) Mode :  L file :  2472627d9b38bce396254ac17b9b3655.png
# Shape :  (128, 128) Mode :  L file :  2508f9cfb3c5f96d4539dcb1fa049d6a.png
# Shape :  (128, 128) Mode :  L file :  2564876058a684e6d899f3575081b16f.png
# Shape :  (128, 128) Mode :  L file :  a20985daaeef78ec36b75a820360ee7e.png
# Shape :  (128, 128) Mode :  L file :  a24271ffaff5625d6d77bd1b8db7f06f.png
# Shape :  (128, 128) Mode :  L file :  a28846718dc9731a9816444c12f3a9d5.png
# Shape :  (128, 128) Mode :  L file :  a2e715a637a43b33199c0991785adab7.png
# Shape :  (128, 128) Mode :  L file :  a31202172eaa14a258079619440394a7.png
# Shape :  (128, 128) Mode :  L file :  a343124f546ea20b08092f6d2e72554f.png
# Shape :  (128, 128) Mode :  L file :  a3902e315de94e425dfd3bd109dc88de.png
# Shape :  (128, 128) Mode :  L file :  a3978283d13463af3d6d98c6ae6d6be7.png
# Shape :  (128, 128) Mode :  L file :  a464044a6cdff5cff44d099a99138ae2.png
# Shape :  (128, 128) Mode :  L file :  a470313562508266ecf17a4a5410fc6f.png
# Shape :  (128, 128) Mode :  L file :  a473790a307fd44bc5e5e68b12bf6f51.png
# Shape :  (128, 128) Mode :  L file :  a515850ab263cc40693e86481e0b3462.png
# Shape :  (128, 128) Mode :  L file :  a570fb86a76eefb5d38a74d029415770.png
# Shape :  (128, 128) Mode :  L file :  a572d8a52f46accacc8eef19acb8759c.png
# Shape :  (128, 128) Mode :  L file :  a607a69c1d589cf0e9d24ff6162abf01.png
# Shape :  (128, 128) Mode :  L file :  a67721b7b84cb6e9649c67168d02274b.png
# Shape :  (128, 128) Mode :  L file :  a749a9c6c906f0f57b9c91d13439bd6b.png
# Shape :  (128, 128) Mode :  L file :  a768fceead79102801131160d76dc08b.png
# Shape :  (128, 128) Mode :  L file :  a804a5a7b1a56f640962a7addd7a8c6f.png
# Shape :  (128, 128) Mode :  L file :  a874d91dfcbe35e7204dce0845bcc71a.png
# Shape :  (128, 128) Mode :  L file :  a8801babe463c8f0e32c2b338bb2acb8.png
# Shape :  (128, 128) Mode :  L file :  a9411d7195ec9ac242d5fcb2f6ebf396.png
# Shape :  (128, 128) Mode :  L file :  a9667850a5652972443b765ae3ccf3ff.png
# Shape :  (128, 128) Mode :  L file :  aa2195acc0c17507e356e60955e30638.png
# Shape :  (128, 128) Mode :  L file :  aa26ed5cf3896639bca34b372a774c4e.png
# Shape :  (128, 128) Mode :  L file :  aa3b4f7caf9de8c1d6551c33045fb4c1.png
# Shape :  (128, 128) Mode :  L file :  aa5b0752be8375e478e7df19747494fd.png
# Shape :  (128, 128) Mode :  L file :  aa61a96b0a18b8dbc65fd20af3644958.png
# Shape :  (128, 128) Mode :  L file :  aa62ae56c20735351461f141d4ede330.png
# Shape :  (128, 128) Mode :  L file :  aab5d03983b5d585608d8ff863f7b3fb.png
# Shape :  (128, 128) Mode :  L file :  ab174fdf91d7381d1f891f93a493ab4c.png
# Shape :  (128, 128) Mode :  L file :  ab1e91e9a308f42d3cd0baa59f7c7c71.png
# Shape :  (128, 128) Mode :  L file :  ab2081739ddb9daf262c79848736d386.png
# Shape :  (128, 128) Mode :  L file :  ab34ca35df5a7be8cbd2fc8df3a2fb7e.png
# Shape :  (128, 128) Mode :  L file :  ab3e3e6a64d42b2ec53685f24192daf3.png
# Shape :  (128, 128) Mode :  L file :  bb11c77bcc275f1f2d409852cef0f016.png
# Shape :  (128, 128) Mode :  L file :  bb187a066f29895b69dc38298ffd72f5.png
# Shape :  (128, 128) Mode :  L file :  bb24d8980818339d65bb77a978b0f4ad.png
# Shape :  (128, 128) Mode :  L file :  bb6bc81243a3d15132b3a2b42e1e5f0e.png
# Shape :  (128, 128) Mode :  L file :  bb7ed6b43f565a1fe2ebcbf99886d1d4.png
# Shape :  (128, 128) Mode :  L file :  bb7f020e3bac66c4d049b0a9d748b63c.png
# Shape :  (128, 128) Mode :  L file :  bbb6f569a59a45dd2d895eda0431b036.png
# Shape :  (128, 128) Mode :  L file :  bc04da26ab41ce92565dd3c686dae6c8.png
# Shape :  (128, 128) Mode :  L file :  bc3d64f2379104d8e69c7e6a883bb08c.png
# Shape :  (128, 128) Mode :  L file :  bc42f3fa484ad950692de70f31a1314c.png
# Shape :  (128, 128) Mode :  L file :  bc65429425aaafea7a29c4992ff33bad.png
# Shape :  (128, 128) Mode :  L file :  bc6699010f8031e38623087db86466b1.png
# Shape :  (128, 128) Mode :  L file :  bcbc7bef972e1b0ad0ebf8d4781aba31.png
# Shape :  (128, 128) Mode :  L file :  bcd5608b3999bb8d454d0903fc3bd759.png
# Shape :  (128, 128) Mode :  L file :  bd0b360b1e221acee0e0ba4970556271.png
# Shape :  (128, 128) Mode :  L file :  bd102f5038b9c07483b7e76eb614de0a.png
# Shape :  (128, 128) Mode :  L file :  bd162a474c3726de6e7b9790feb95a00.png
# Shape :  (128, 128) Mode :  L file :  bd2dc6a591234f7855101bb3e66c96c8.png
# Shape :  (128, 128) Mode :  L file :  bd514860151bb8fcfb448276821f0ac9.png
# Shape :  (128, 128) Mode :  L file :  bd993ecb7172acc9508e2d74fa239e6c.png
# Shape :  (128, 128) Mode :  L file :  bdaed1accdd28cf71be52229b654c0fd.png
# Shape :  (128, 128) Mode :  L file :  be015078936ab89c8c755cf290ba9a0f.png
# Shape :  (128, 128) Mode :  L file :  be05023fef0c596b1691471cb7095d12.png
# Shape :  (128, 128) Mode :  L file :  be07c00a9019c724132920b410951478.png
# Shape :  (128, 128) Mode :  L file :  be3c9e989860de924073c3b60aae71bd.png
# Shape :  (128, 128) Mode :  L file :  be51269d525b84339af824a319814cda.png
# Shape :  (128, 128) Mode :  L file :  bea810fbe5f0ee59c79b4ebd4732f1a0.png
# Shape :  (128, 128) Mode :  L file :  bed7b44e6d413d740c97696f475ab858.png
# Shape :  (128, 128) Mode :  L file :  bedffe5f780e3c2be2cc032450ce0800.png
# Shape :  (128, 128) Mode :  L file :  bf3bbec50ea288905e42bbfaf2c682bc.png
# Shape :  (128, 128) Mode :  L file :  bf44b8a1a00a2e525426a4ad4bedfff9.png
# Shape :  (128, 128) Mode :  L file :  bfd1934c21fe48a0e3ad8e9695473cb8.png
# Shape :  (128, 128) Mode :  L file :  c01eb038f84397e1116a56414e16fcee.png
# Shape :  (128, 128) Mode :  L file :  c0200dcf86e0c83a600efc4029561dbd.png
# Shape :  (128, 128) Mode :  L file :  c0a07e462960bd1eb37b5b0c1753c0fa.png
# Shape :  (128, 128) Mode :  L file :  c15b8f5dfe00c18107ba52ce25fc33e0.png
# Shape :  (128, 128) Mode :  L file :  c168467ba25e8675a50b85be4204b4b2.png
# Shape :  (128, 128) Mode :  L file :  c1cf5dc8ab6e95cca71eb2cc0716a14b.png
# Shape :  (128, 128) Mode :  L file :  c1e51c1b53a96730b28df479028e1793.png
# Shape :  (128, 128) Mode :  L file :  c22d2d0168ef819997238082b12d4149.png
# Shape :  (128, 128) Mode :  L file :  c239a9a08c352ec88ad81d4099e0ebcb.png
# Shape :  (128, 128) Mode :  L file :  c26d812059636151e2d7264fa0a9fdbc.png
# Shape :  (128, 128) Mode :  L file :  c2ccae30ccc8189fe03319b604cdde8b.png
# Shape :  (128, 128) Mode :  L file :  c2ced35e09624934e6ac8ea922d6f216.png
# Shape :  (128, 128) Mode :  L file :  c2e9e25b3f224a2bc80ca1f6dd86f465.png
# Shape :  (128, 128) Mode :  L file :  c31172b1b6021532294f78da3b65fdc3.png
# Shape :  (128, 128) Mode :  L file :  c328943933b839c4f9d2d0c94a831eab.png
# Shape :  (128, 128) Mode :  L file :  c33078039ff93c70014ebe16192be997.png
# Shape :  (128, 128) Mode :  L file :  c36f07e5793cef38dd7ab17764fce3e4.png
# Shape :  (128, 128) Mode :  L file :  c37baac7c0837959e870e95d4606914e.png
# Shape :  (128, 128) Mode :  L file :  c3cd547094fa52e65a22228bba5ef189.png
# Shape :  (128, 128) Mode :  L file :  c3faf90e9db3afcdafad8f283af02f2d.png
# Shape :  (128, 128) Mode :  L file :  c414179415b146d9cbeca0fb3fb351a7.png
# Shape :  (128, 128) Mode :  L file :  c4249fa108dfc8cc6617d0c03adaa9e4.png
# Shape :  (128, 128) Mode :  L file :  c4a8492e6d60e15a32a52b5ebee00f65.png
# Shape :  (128, 128) Mode :  L file :  c6216855a09754f487980c889f7a8732.png
# Shape :  (128, 128) Mode :  L file :  c658e082c4a76075a2f91c731b1f79a0.png
# Shape :  (128, 128) Mode :  L file :  c66c01633c25f6b9861578432638508d.png
# Shape :  (128, 128) Mode :  L file :  c69b802e0fee0c78988bd1878a4a66be.png
# Shape :  (128, 128) Mode :  L file :  c6ae44ca12707711f81c0380408db48d.png
# Shape :  (128, 128) Mode :  L file :  c6b5dc9a4db605cdc15a51d4bd6cb228.png
# Shape :  (128, 128) Mode :  L file :  c6c43b9a036bde516d4525d97f2c8223.png
# Shape :  (128, 128) Mode :  L file :  c6d6089b4ea367333ca025d8cd1c8d33.png
# Shape :  (128, 128) Mode :  L file :  c6e38b5fcc7d77df53dd101605d68b92.png
# Shape :  (128, 128) Mode :  L file :  c6fd81dc1179711b70fa379eeb714028.png
# Shape :  (128, 128) Mode :  L file :  c7442bb2aefb0ce9062694a697f5c4aa.png
# Shape :  (128, 128) Mode :  L file :  c78759a7396dd709da30a25683b6219c.png
# Shape :  (128, 128) Mode :  L file :  c7aaa5080c49117748fce73bff068573.png
# Shape :  (128, 128) Mode :  L file :  c7aaa7d7e4c6c0693b4cdd222cb10353.png
# Shape :  (128, 128) Mode :  L file :  c7bebc1bd86c69b8117482029f8506f2.png
# Shape :  (128, 128) Mode :  L file :  c7cbba822ab211cd0292b3688aa4b903.png
# Shape :  (128, 128) Mode :  L file :  c7eff213225543a37732bbe719485211.png
# Shape :  (128, 128) Mode :  L file :  c834e3170c81cebd468accb10ef07c1f.png
# Shape :  (128, 128) Mode :  L file :  c86cb7e7cf51b7b182a6ffa8b253ed2b.png
# Shape :  (128, 128) Mode :  L file :  c88f1d27e73aaec5556fcd439600879f.png
# Shape :  (128, 128) Mode :  L file :  c890621aeaafe9b0e353f29a7d93391d.png
# Shape :  (128, 128) Mode :  L file :  c9171cef5cbaa557cfda9c22532e74c3.png
# Shape :  (128, 128) Mode :  L file :  c9474f64767e4be134be6ce815240137.png
# Shape :  (128, 128) Mode :  L file :  c9699a289977ce2d80c6e073eadf8b2a.png
# Shape :  (128, 128) Mode :  L file :  c9df6c726d44834138a89684b2454dbb.png
# Shape :  (128, 128) Mode :  L file :  ca15c22f95aeed95acafe3045f1f2862.png
# Shape :  (128, 128) Mode :  L file :  ca472f184807aded538221ac0b5ac27b.png
# Shape :  (128, 128) Mode :  L file :  ca76eefff717b507a0eba5353324d9e5.png
# Shape :  (128, 128) Mode :  L file :  ca8d2d96f0802516c94fa60dbae9e0eb.png
# Shape :  (128, 128) Mode :  L file :  ca8f5bc4dfc11f10d823230e1c800caf.png
# Shape :  (128, 128) Mode :  L file :  caa67ad39a42b14c19c572ccc5fd2243.png
# Shape :  (128, 128) Mode :  L file :  cab8ac89fc001f1adb2ff4d8b3f9f9a9.png
# Shape :  (128, 128) Mode :  L file :  cabf04859faf2895703dff425ff2277b.png
# Shape :  (128, 128) Mode :  L file :  cb4d47e95b84ec3eee1796bc8fff1180.png
# Shape :  (128, 128) Mode :  L file :  cb5dece724ab947f6a615c7fe1f8c380.png
# Shape :  (128, 128) Mode :  L file :  cb6206518534074f8981cb93da4283be.png
# Shape :  (128, 128) Mode :  L file :  cb73316904b4dfa07e2f0066fdc91242.png
# Shape :  (128, 128) Mode :  L file :  cb905e8bb50be791b394e69b45bfd8da.png
# Shape :  (128, 128) Mode :  L file :  cbf35bfeb900387380e043ef4523ed7a.png
# Shape :  (128, 128) Mode :  L file :  cbf729aea39780adc2e5a7a23c8f5c21.png
# Shape :  (128, 128) Mode :  L file :  cc0c8e75290550c68a73f399760512a9.png
# Shape :  (128, 128) Mode :  L file :  cc1234027ede8d9006ce01f0cd12b710.png
# Shape :  (128, 128) Mode :  L file :  cc263a4c9ff9943acbb9049f637a0bed.png
# Shape :  (128, 128) Mode :  L file :  cca2b0e3882574e1d8709e0f95c42565.png
# Shape :  (128, 128) Mode :  L file :  cccbca215f38e9a03c46f73265bba889.png
# Shape :  (128, 128) Mode :  L file :  ccedb1eb235f5dedddc443b93e9aaabd.png
# Shape :  (128, 128) Mode :  L file :  cd22077ab23004ae566c5e09cecee05f.png
# Shape :  (128, 128) Mode :  L file :  cd23dec47118e009aa9ae014362be38f.png
# Shape :  (128, 128) Mode :  L file :  cd37a14624e4d3b04584b054ec761314.png
# Shape :  (128, 128) Mode :  L file :  cd9b2df963652cea69a16b7e368cd7f1.png
# Shape :  (128, 128) Mode :  L file :  cdce0701fa96db632af5facf074fe654.png
# Shape :  (128, 128) Mode :  L file :  ce03344d71dca420b3ea36e8e8c48219.png
# Shape :  (128, 128) Mode :  L file :  ce05c962f695932a830ad4356d7a3e04.png
# Shape :  (128, 128) Mode :  L file :  ce4df5feb17e4951e1151a4ddf38b5e5.png
# Shape :  (128, 128) Mode :  L file :  ce571df8dd7ac27523b2cca4cbc32194.png
# Shape :  (128, 128) Mode :  L file :  ce5cd74980494117a495a305ed5fe95b.png
# Shape :  (128, 128) Mode :  L file :  ce6a3e19dfcd8e8b162faf8511b920ae.png
# Shape :  (128, 128) Mode :  L file :  ce6fc3053fb6221f93f5c376a005e658.png
# Shape :  (128, 128) Mode :  L file :  ceb9fcd4486cd56c04bf66804cfee9f0.png
# Shape :  (128, 128) Mode :  L file :  cebf26e8911e2a38c273b1c015e61fcd.png
# Shape :  (128, 128) Mode :  L file :  cf130a9fff498616cc88d3f754fc50d3.png
# Shape :  (128, 128) Mode :  L file :  cf3eef59fe32392bef1dd5d18e79207b.png
# Shape :  (128, 128) Mode :  L file :  cfb77b3822d05b280d51e8259f0c2ff4.png
# Shape :  (128, 128) Mode :  L file :  d0122ee951d52ee1198b9c402c0a75bf.png
# Shape :  (128, 128) Mode :  L file :  d09aedf8c4f0622413bf67f8e5715bcf.png
# Shape :  (128, 128) Mode :  L file :  d0c156d5cf865a9e43e20c1798093bf0.png
# Shape :  (128, 128) Mode :  L file :  d114ce94a3994d16e43a4de93fe72e17.png
# Shape :  (128, 128) Mode :  L file :  d12f8acae725c66b00c31c3c96978e18.png
# Shape :  (128, 128) Mode :  L file :  d13e3749938f9bcd3945bed229d40bb7.png
# Shape :  (128, 128) Mode :  L file :  d1600f32364c41f754e31087db6dd7d2.png
# Shape :  (128, 128) Mode :  L file :  d1887e997c7035c12a04dd88ca0306b6.png
# Shape :  (128, 128) Mode :  L file :  d1e6b20063dfb294189b8338541ba1cf.png
# Shape :  (128, 128) Mode :  L file :  d22f7eb37563c080925a4cacbed16c7f.png
# Shape :  (128, 128) Mode :  L file :  d23a8024cc5a377ecfdabb3577e96f10.png
# Shape :  (128, 128) Mode :  L file :  d2553a38aa5977fedd9c365d6129f83d.png
# Shape :  (128, 128) Mode :  L file :  d257675d358d70474a86b4e11dba33a9.png
# Shape :  (128, 128) Mode :  L file :  d27e776a3f9b648e478a77229de52b54.png
# Shape :  (128, 128) Mode :  L file :  d2d7c3bf0395220f58bdc48df5a9c8d6.png
# Shape :  (128, 128) Mode :  L file :  d3178109fc141fbce7c7d2c97a9e03d8.png
# Shape :  (128, 128) Mode :  L file :  d321ba188146edd239c266f409e7995e.png
# Shape :  (128, 128) Mode :  L file :  d3389a52075cb3af01ee0b164c75019d.png
# Shape :  (128, 128) Mode :  L file :  d34431a82f1e24ef7ef228dae9eb8c4c.png
# Shape :  (128, 128) Mode :  L file :  d38f15e7ee1656b427fc23cea9944691.png
# Shape :  (128, 128) Mode :  L file :  d402dcd0cbd09bcc950a22003b8251b4.png
# Shape :  (128, 128) Mode :  L file :  d40f3ba9fd4d86bd79dd02a5104c16c1.png
# Shape :  (128, 128) Mode :  L file :  d4aff0ad5f4f99fc6cad4243b926eda7.png
# Shape :  (128, 128) Mode :  L file :  d4c52c98840e8128d50e0cd73068ccd3.png
# Shape :  (128, 128) Mode :  L file :  d4e7b59257c600b426046bed3a7da516.png
# Shape :  (128, 128) Mode :  L file :  d4fed2657cb159dd112be532b7678d20.png
# Shape :  (128, 128) Mode :  L file :  d50705dec19859abe19deb5c3af5f3bd.png
# Shape :  (128, 128) Mode :  L file :  d507e807f025f09ea0cff40b52e9322c.png
# Shape :  (128, 128) Mode :  L file :  d52264908b734ce04d2f4da2a07f531d.png
# Shape :  (128, 128) Mode :  L file :  d531b1cefbdd804a28399c46965aba52.png
# Shape :  (128, 128) Mode :  L file :  d55e4723d6de869b76020bcc1c4cfa26.png
# Shape :  (128, 128) Mode :  L file :  d5e9b0e1fd8aa49e0e483cd1bef9d61e.png
# Shape :  (128, 128) Mode :  L file :  d6388ee9f63e1111d41ce66ddf06ff41.png
# Shape :  (128, 128) Mode :  L file :  d64f0d1c4c3e893b1d0f3aa5b9967830.png
# Shape :  (128, 128) Mode :  L file :  d6691d2689957ed83dcdfe315f29e2e9.png
# Shape :  (128, 128) Mode :  L file :  d6933d2484b99d63cab5532c478f82bc.png
# Shape :  (128, 128) Mode :  L file :  d6c24dd444b8b840d764a26f18e1d0e0.png
# Shape :  (128, 128) Mode :  L file :  d6e8a819330b7e0ff527d3daa11601ed.png
# Shape :  (128, 128) Mode :  L file :  d6f1c10e0059e0ac468537ceac0f22e1.png
# Shape :  (128, 128) Mode :  L file :  d732d32a9f1f809558e32f88e500bb55.png
# Shape :  (128, 128) Mode :  L file :  d750d162ee3c1ae81da9b64d52a3f9ee.png
# Shape :  (128, 128) Mode :  L file :  d7632c418ab10443dbeddc264ec032fb.png
# Shape :  (128, 128) Mode :  L file :  d76330914587add652997eda2c3caa98.png
# Shape :  (128, 128) Mode :  L file :  d78caa6909f1270cd3e8e216c24f6909.png
# Shape :  (128, 128) Mode :  L file :  d7907191ca56c0adca3df658743028e3.png
# Shape :  (128, 128) Mode :  L file :  d83840fbd3cde13ca6b801a3800e3c2b.png
# Shape :  (128, 128) Mode :  L file :  d85e113fd3d5feeaccc27c66a2ac7c29.png
# Shape :  (128, 128) Mode :  L file :  d86c77402f58687283542ae735f327f8.png
# Shape :  (128, 128) Mode :  L file :  d87fb93838434f8a1d668c0ed1bd8824.png
# Shape :  (128, 128) Mode :  L file :  d8a029939bb6e3c8960e477176f08a15.png
# Shape :  (128, 128) Mode :  L file :  d8caba69142706f17ca9db4a760b7490.png
# Shape :  (128, 128) Mode :  L file :  d8edc14c38478d80b27a0bc6d41dc4ae.png
# Shape :  (128, 128) Mode :  L file :  d8fd021d1ca1e21880a0b84effa7157b.png
# Shape :  (128, 128) Mode :  L file :  d90d1935c16712717b15cb9d29a2dd9f.png
# Shape :  (128, 128) Mode :  L file :  d918eeffd78047944ec2d97c4594eb8b.png
# Shape :  (128, 128) Mode :  L file :  d958cd2313d0c5eb6d55c9d96c25c8b8.png
# Shape :  (128, 128) Mode :  L file :  d9634e2f8c7644c545c03c60f76750ef.png
# Shape :  (128, 128) Mode :  L file :  d96f2bcd580fa5de490377169d6a45bd.png
# Shape :  (128, 128) Mode :  L file :  d9b9f5db7d29a3855cceef574145b595.png
# Shape :  (128, 128) Mode :  L file :  d9be92214b9b151afa53a2debdd6acc6.png
# Shape :  (128, 128) Mode :  L file :  da51285c1f90d4b22b4be4e9d0ac63aa.png
# Shape :  (128, 128) Mode :  L file :  da69d49cc6fd90ae7a2d494009ef46cf.png
# Shape :  (128, 128) Mode :  L file :  da87f75ad935467d3c8d0ab08a559e76.png
# Shape :  (128, 128) Mode :  L file :  daa767cd9cc041a3b7a340528689adab.png
# Shape :  (128, 128) Mode :  L file :  dbe57dd8b2e7b7349a37705965bc889f.png
# Shape :  (128, 128) Mode :  L file :  dcc2c41c810408c4cb08ce092a712d02.png
# Shape :  (128, 128) Mode :  L file :  de7b3bfcf24632b26291ad01e272cafa.png
# Shape :  (128, 128) Mode :  L file :  deb7cc4263e3dc9a640c57c7b2f714fd.png
# Shape :  (128, 128) Mode :  L file :  dedfc7b72b5c7ce42bd3e93df033a531.png
# Shape :  (128, 128) Mode :  L file :  df2cf775afbb1d2880aa22f5f3c43995.png
# Shape :  (128, 128) Mode :  L file :  df2f15d3d496f356e95aaf027d17dcaa.png
# Shape :  (128, 128) Mode :  L file :  e025b80af56ce319d0a02bd97a086768.png
# Shape :  (128, 128) Mode :  L file :  e1795634a3bf20d9c2e313a92c048bad.png
# Shape :  (128, 128) Mode :  L file :  e2a45c5c31400c8a16df285a45be6900.png
# Shape :  (128, 128) Mode :  L file :  e2e90ac338d909cd708d904145d5c932.png
# Shape :  (128, 128) Mode :  L file :  e3137a7b21d07b4daa8a23cf778cc083.png
# Shape :  (128, 128) Mode :  L file :  e3f10dc9b7dfcf91efd0bce8bf2c82b0.png
# Shape :  (128, 128) Mode :  L file :  e3f297c613666f68896094cb58838ae6.png
# Shape :  (128, 128) Mode :  L file :  e44cb44a7cf02f5c4f9f4c2f0f62f3ce.png
# Shape :  (128, 128) Mode :  L file :  e6764ef0fb7a2a0b624b554c89c62137.png
# Shape :  (128, 128) Mode :  L file :  e7b762a90a95ff8d71497a6da103f649.png
# Shape :  (128, 128) Mode :  L file :  e81d4326a9aba0df4346edaf4e64c0d0.png
# Shape :  (128, 128) Mode :  L file :  e8540972740aa21638731940c3bebe42.png
# Shape :  (128, 128) Mode :  L file :  e92c3770990b6a1fc78bc068a2e03b29.png
# Shape :  (128, 128) Mode :  L file :  eba3f828ff79dc2f173e8f18bfcb8b4c.png
# Shape :  (128, 128) Mode :  L file :  ed989064f7fbdd958ff3c242e4cdabeb.png
# Shape :  (128, 128) Mode :  L file :  edb9414156ff96adf906cbba292e6cd4.png
# Shape :  (128, 128) Mode :  L file :  eded2f92d413246c29001c448dbddd1b.png
# Shape :  (128, 128) Mode :  L file :  eee3361e4c383c67789ef99c3a65fa8d.png
# Shape :  (128, 128) Mode :  L file :  f0b605154f22ad7249c804668dcac3dd.png
# Shape :  (128, 128) Mode :  L file :  f0d05a2fce59b068846bd1c8453d7d89.png
# Shape :  (128, 128) Mode :  L file :  f0da2ba0cdf1426911f59dec320cd9a2.png
# Shape :  (128, 128) Mode :  L file :  f0e435860a2dc27294bf153d56351b27.png
# Shape :  (128, 128) Mode :  L file :  f95d94a3a6384059a64725f89677e885.png
# Shape :  (128, 128) Mode :  L file :  fce1efb32a85a7f67f959a7c37f1f52b.png
# Shape :  (128, 128) Mode :  L file :  fdf110fa789efa05114811412f54b2a9.png
# Shape :  (128, 128) Mode :  L file :  fedd664fb16748292deb66f75e1da4bc.png
# Time taken to run this cell : 0:00:07.929061

# %%
fake_path  = "C:/Users/Administrator/Documents/Datasets/Image Forensic Challenge/phase-01-training/dataset-dist/phase-01/training/fake/fake_grey_128/"
mask_path = "C:/Users/Administrator/Documents/Datasets/Image Forensic Challenge/phase-01-training/dataset-dist/phase-01/training/maskfiles/mask_128/"

# %%
fake_file_names = os.listdir(fake_path)
mask_file_names = os.listdir(mask_path)

# %%
len(mask_file_names),len(fake_file_names)
# Out:
# (450, 450)

# %%
mask_images=[]
for file in mask_file_names:
    try:
        img=imread(mask_path+file)
    except FileNotFoundError:
        print("No file found")
    
    mask_images.append(img)


# Convert grayscale images to binary
binaries=[]

for grayscale in mask_images:
    blur = cv2.GaussianBlur(grayscale,(5,5),0)
    ret,th = cv2.threshold(blur,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
    binaries.append(th)


    
fake_images=[]
for file in fake_file_names:
    try:
        img=imread(fake_path+file)
    except FileNotFoundError:
        print("No file found")
    
    fake_images.append(img)

# %%
plt.imshow(mask_images[0])

# %%
plt.imshow(binaries[0])

# %%
plt.imshow(fake_images[0])

# %%
mask_images_arr = np.array(binaries)
fake_images_arr = np.array(fake_images)
type(mask_images_arr),type(fake_images_arr)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
fake_images_arr.shape,mask_images_arr.shape
# Out:
# ((450, 128, 128), (450, 128, 128))

# %%
if K.image_data_format() == 'channels_first':
    fake_images_arr = fake_images_arr.reshape(fake_images_arr.shape[0], 1, 128, 128)
    mask_images_arr = mask_images_arr.reshape(mask_images_arr.shape[0], 1, 128, 128)
    input_shape = (1, 128, 128)
else:
    fake_images_arr = fake_images_arr.reshape(fake_images_arr.shape[0], 128, 128, 1)
    mask_images_arr = mask_images_arr.reshape(mask_images_arr.shape[0], 128, 128, 1)
    input_shape = (128, 128, 1)

# %%
X = fake_images_arr.astype('float32')
y = mask_images_arr.astype('float32')

# Normalizing the data
X /= 255
y /= 255

print('X shape:', X.shape)
print('y shape:', y.shape)
print(X.shape[0], 'train samples')
print(y.shape[0], 'labels')
# Out:
# X shape: (450, 128, 128, 1)
# y shape: (450, 128, 128, 1)
# 450 train samples
# 450 labels

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=42)

# %%
# https://stackoverflow.com/questions/51844995/how-do-i-implement-a-loss-function-intersection-over-union-for-a-sequential-mo
def iou(true, pred):

    intersection = true * pred

    notTrue = 1 - true
    union = true + (notTrue * pred)

    return K.sum(intersection)/K.sum(union)

def iou_metric(y_true, y_pred, smooth=1.):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection = K.sum(y_true_f * y_pred_f)
    return (intersection + smooth) / (K.sum(y_true_f) + K.sum(y_pred_f) - intersection + smooth)

# %%
def conv2d_block(input_tensor, n_filters, kernel_size = 3, batchnorm = True):
    """Function to add 2 convolutional layers with the parameters passed to it"""
    # first layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    # second layer
    x = Conv2D(filters = n_filters, kernel_size = (kernel_size, kernel_size),\
              kernel_initializer = 'he_normal', padding = 'same')(input_tensor)
    if batchnorm:
        x = BatchNormalization()(x)
    x = Activation('relu')(x)
    
    return x

# %%
def get_unet(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
del model

# %%
input_img = Input((128, 128, 1), name='img')
model = get_unet(input_img, n_filters=16, dropout=0, batchnorm=False)
model.compile(optimizer=optimizers.Adam(), loss="binary_crossentropy", metrics=[iou])

# %%
model.summary()
# Out:
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                (None, 128, 128, 1)  0
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 16) 160         img[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, 128, 128, 16) 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 16)   0           activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_9 (Dropout)             (None, 64, 64, 16)   0           max_pooling2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 64, 64, 32)   4640        dropout_9[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, 64, 64, 32)   0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 32)   0           activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_10 (Dropout)            (None, 32, 32, 32)   0           max_pooling2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 32, 32, 64)   18496       dropout_10[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, 32, 32, 64)   0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_7 (MaxPooling2D)  (None, 16, 16, 64)   0           activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_11 (Dropout)            (None, 16, 16, 64)   0           max_pooling2d_7[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 16, 16, 128)  73856       dropout_11[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, 16, 16, 128)  0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)  (None, 8, 8, 128)    0           activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_12 (Dropout)            (None, 8, 8, 128)    0           max_pooling2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 8, 8, 256)    295168      dropout_12[0][0]
# __________________________________________________________________________________________________
# activation_28 (Activation)      (None, 8, 8, 256)    0           conv2d_29[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 16, 16, 128)  295040      activation_28[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 16, 16, 256)  0           conv2d_transpose_5[0][0]
#                                                                  activation_26[0][0]
# __________________________________________________________________________________________________
# dropout_13 (Dropout)            (None, 16, 16, 256)  0           concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 16, 16, 128)  295040      dropout_13[0][0]
# __________________________________________________________________________________________________
# activation_30 (Activation)      (None, 16, 16, 128)  0           conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 32, 32, 64)   73792       activation_30[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 32, 32, 128)  0           conv2d_transpose_6[0][0]
#                                                                  activation_24[0][0]
# __________________________________________________________________________________________________
# dropout_14 (Dropout)            (None, 32, 32, 128)  0           concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 32, 32, 64)   73792       dropout_14[0][0]
# __________________________________________________________________________________________________
# activation_32 (Activation)      (None, 32, 32, 64)   0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 64, 64, 32)   18464       activation_32[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 64, 64, 64)   0           conv2d_transpose_7[0][0]
#                                                                  activation_22[0][0]
# __________________________________________________________________________________________________
# dropout_15 (Dropout)            (None, 64, 64, 64)   0           concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 64, 64, 32)   18464       dropout_15[0][0]
# __________________________________________________________________________________________________
# activation_34 (Activation)      (None, 64, 64, 32)   0           conv2d_35[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 128, 128, 16) 4624        activation_34[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 128, 128, 32) 0           conv2d_transpose_8[0][0]
#                                                                  activation_20[0][0]
# __________________________________________________________________________________________________
# dropout_16 (Dropout)            (None, 128, 128, 32) 0           concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 128, 128, 16) 4624        dropout_16[0][0]
# __________________________________________________________________________________________________
# activation_36 (Activation)      (None, 128, 128, 16) 0           conv2d_37[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 128, 128, 1)  17          activation_36[0][0]
# ==================================================================================================
# Total params: 1,176,177
# Trainable params: 1,176,177
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-seg_iou_3.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

# %%
results = model.fit(X_train, y_train, batch_size=64, epochs=50, callbacks=callbacks,\
                    validation_data=(X_test, y_test))
# Out:
# Train on 360 samples, validate on 90 samples
# Epoch 1/50
# 360/360 [==============================] - 56s 156ms/step - loss: 0.3479 - iou: 0.7792 - val_loss: 0.2833 - val_iou: 0.8399
#
# Epoch 00001: val_loss improved from inf to 0.28332, saving model to model-seg_iou_3.h5
# Epoch 2/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2917 - iou: 0.8464 - val_loss: 0.2767 - val_iou: 0.8427
#
# Epoch 00002: val_loss improved from 0.28332 to 0.27668, saving model to model-seg_iou_3.h5
# Epoch 3/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2803 - iou: 0.8593 - val_loss: 0.2630 - val_iou: 0.8557
#
# Epoch 00003: val_loss improved from 0.27668 to 0.26301, saving model to model-seg_iou_3.h5
# Epoch 4/50
# 360/360 [==============================] - 58s 160ms/step - loss: 0.2699 - iou: 0.8628 - val_loss: 0.2497 - val_iou: 0.8780
#
# Epoch 00004: val_loss improved from 0.26301 to 0.24973, saving model to model-seg_iou_3.h5
# Epoch 5/50
# 360/360 [==============================] - 58s 160ms/step - loss: 0.2705 - iou: 0.8553 - val_loss: 0.2460 - val_iou: 0.8748
#
# Epoch 00005: val_loss improved from 0.24973 to 0.24602, saving model to model-seg_iou_3.h5
# Epoch 6/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2596 - iou: 0.8667 - val_loss: 0.2498 - val_iou: 0.8489
#
# Epoch 00006: val_loss did not improve from 0.24602
# Epoch 7/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2599 - iou: 0.8665 - val_loss: 0.2461 - val_iou: 0.8503
#
# Epoch 00007: val_loss did not improve from 0.24602
# Epoch 8/50
# 360/360 [==============================] - 58s 162ms/step - loss: 0.2642 - iou: 0.8460 - val_loss: 0.2395 - val_iou: 0.8838
#
# Epoch 00008: val_loss improved from 0.24602 to 0.23950, saving model to model-seg_iou_3.h5
# Epoch 9/50
# 360/360 [==============================] - 58s 160ms/step - loss: 0.2548 - iou: 0.8662 - val_loss: 0.2373 - val_iou: 0.8765
#
# Epoch 00009: val_loss improved from 0.23950 to 0.23730, saving model to model-seg_iou_3.h5
# Epoch 10/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2529 - iou: 0.8712 - val_loss: 0.2401 - val_iou: 0.8567
#
# Epoch 00010: val_loss did not improve from 0.23730
# Epoch 11/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2549 - iou: 0.8668 - val_loss: 0.2435 - val_iou: 0.8485
#
# Epoch 00011: val_loss did not improve from 0.23730
# Epoch 12/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2523 - iou: 0.8654 - val_loss: 0.2357 - val_iou: 0.8846
#
# Epoch 00012: val_loss improved from 0.23730 to 0.23574, saving model to model-seg_iou_3.h5
# Epoch 13/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2507 - iou: 0.8679 - val_loss: 0.2319 - val_iou: 0.8727
#
# Epoch 00013: val_loss improved from 0.23574 to 0.23187, saving model to model-seg_iou_3.h5
# Epoch 14/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2481 - iou: 0.8713 - val_loss: 0.2335 - val_iou: 0.8704
#
# Epoch 00014: val_loss did not improve from 0.23187
# Epoch 15/50
# 360/360 [==============================] - 58s 162ms/step - loss: 0.2484 - iou: 0.8727 - val_loss: 0.2355 - val_iou: 0.8616
#
# Epoch 00015: val_loss did not improve from 0.23187
# Epoch 16/50
# 360/360 [==============================] - 61s 168ms/step - loss: 0.2537 - iou: 0.8638 - val_loss: 0.2348 - val_iou: 0.8688
#
# Epoch 00016: val_loss did not improve from 0.23187
# Epoch 17/50
# 360/360 [==============================] - 60s 167ms/step - loss: 0.2507 - iou: 0.8635 - val_loss: 0.2319 - val_iou: 0.8925
#
# Epoch 00017: val_loss did not improve from 0.23187
# Epoch 18/50
# 360/360 [==============================] - 65s 180ms/step - loss: 0.2495 - iou: 0.8671 - val_loss: 0.2310 - val_iou: 0.8928
#
# Epoch 00018: val_loss improved from 0.23187 to 0.23101, saving model to model-seg_iou_3.h5
# Epoch 19/50
# 360/360 [==============================] - 61s 170ms/step - loss: 0.2525 - iou: 0.8651 - val_loss: 0.2321 - val_iou: 0.8721
#
# Epoch 00019: val_loss did not improve from 0.23101
# Epoch 20/50
# 360/360 [==============================] - 63s 175ms/step - loss: 0.2458 - iou: 0.8816 - val_loss: 0.2300 - val_iou: 0.8786
#
# Epoch 00020: val_loss improved from 0.23101 to 0.23002, saving model to model-seg_iou_3.h5
# Epoch 21/50
# 360/360 [==============================] - 59s 163ms/step - loss: 0.2458 - iou: 0.8676 - val_loss: 0.2298 - val_iou: 0.8934
#
# Epoch 00021: val_loss improved from 0.23002 to 0.22976, saving model to model-seg_iou_3.h5
# Epoch 22/50
# 360/360 [==============================] - 64s 177ms/step - loss: 0.2460 - iou: 0.8695 - val_loss: 0.2305 - val_iou: 0.8768
#
# Epoch 00022: val_loss did not improve from 0.22976
# Epoch 23/50
# 360/360 [==============================] - 62s 172ms/step - loss: 0.2445 - iou: 0.8821 - val_loss: 0.2421 - val_iou: 0.8469
#
# Epoch 00023: val_loss did not improve from 0.22976
# Epoch 24/50
# 360/360 [==============================] - 61s 170ms/step - loss: 0.2492 - iou: 0.8605 - val_loss: 0.2308 - val_iou: 0.8946
#
# Epoch 00024: val_loss did not improve from 0.22976
# Epoch 25/50
# 360/360 [==============================] - 66s 183ms/step - loss: 0.2461 - iou: 0.8672 - val_loss: 0.2300 - val_iou: 0.8810
#
# Epoch 00025: val_loss did not improve from 0.22976
# Epoch 26/50
# 360/360 [==============================] - 60s 167ms/step - loss: 0.2435 - iou: 0.8815 - val_loss: 0.2342 - val_iou: 0.8628
#
# Epoch 00026: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00026: val_loss did not improve from 0.22976
# Epoch 27/50
# 360/360 [==============================] - 61s 169ms/step - loss: 0.2422 - iou: 0.8619 - val_loss: 0.2309 - val_iou: 0.8738
#
# Epoch 00027: val_loss did not improve from 0.22976
# Epoch 28/50
# 360/360 [==============================] - 58s 162ms/step - loss: 0.2397 - iou: 0.8751 - val_loss: 0.2300 - val_iou: 0.8861
#
# Epoch 00028: val_loss did not improve from 0.22976
# Epoch 29/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2400 - iou: 0.8831 - val_loss: 0.2302 - val_iou: 0.8870
#
# Epoch 00029: val_loss did not improve from 0.22976
# Epoch 30/50
# 360/360 [==============================] - 59s 163ms/step - loss: 0.2388 - iou: 0.8778 - val_loss: 0.2307 - val_iou: 0.8758
#
# Epoch 00030: val_loss did not improve from 0.22976
# Epoch 31/50
# 360/360 [==============================] - 58s 161ms/step - loss: 0.2388 - iou: 0.8711 - val_loss: 0.2305 - val_iou: 0.8764
#
# Epoch 00031: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00031: val_loss did not improve from 0.22976
# Epoch 00031: early stopping

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test iou:', score[1])
# Out:
# Test loss: 0.23053367071681552
# Test iou: 0.8764401541815864

# %%
plt.figure(figsize=(5,5))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize=(5,5))
plt.title("Learning curve")
plt.plot(results.history["iou"], label="IOU")
plt.plot(results.history["val_iou"], label="val_IOU")
plt.plot( np.argmin(results.history["val_iou"]), np.min(results.history["val_iou"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("IOU")
plt.legend();

# %%
# load the best model
model.load_weights('model-seg_iou_3.h5')
# Evaluate on validation set (this must be equals to the best log_loss)
model.evaluate(X_test, y_test, verbose=1)
# Out:
# 90/90 [==============================] - 4s 47ms/step
# [0.22976434893078274, 0.8934207346704272]

# %%
# Predict on train, val and test
preds_train = model.predict(X_train, verbose=1)
preds_val = model.predict(X_test, verbose=1)

preds_train_t = (preds_train > 0.5).astype(np.uint8)
preds_val_t = (preds_val > 0.5).astype(np.uint8)
# Out:
# 360/360 [==============================] - 17s 47ms/step
# 90/90 [==============================] - 4s 47ms/step

# %%
def plot_sample(X, y, preds, binary_preds, ix=None):
    """Function to plot the results"""
    if ix is None:
        ix = random.randint(0, len(X))

    has_mask = y[ix].max() > 0

    fig, ax = plt.subplots(1, 4, figsize=(20, 10))
    ax[0].imshow(X[ix], cmap='seismic')
    if has_mask:
        ax[0].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[0].set_title('original')

    ax[1].imshow(y[ix].squeeze())
    ax[1].set_title('mask')

    ax[2].imshow(preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[2].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[2].set_title(' Predicted')
    
    ax[3].imshow(binary_preds[ix].squeeze(), vmin=0, vmax=1)
    if has_mask:
        ax[3].contour(y[ix].squeeze(), colors='k', levels=[0.5])
    ax[3].set_title(' Predicted binary');

# %%
# Check if training data looks all right
#plot_sample(X_train, y_train, preds_train, preds_train_t, ix=50)

# %%
# Check if valid data looks all right
#plot_sample(X_test, y_test, preds_val, preds_val_t, ix=13)

# %%
plt.imshow(y_train[13].squeeze(), vmin=0, vmax=1)

# %%
plt.imshow(preds_val[13].squeeze())

# %%
plt.imshow(preds_train[25].squeeze())

# %%
def get_unet1(input_img, n_filters = 16, dropout = 0.1, batchnorm = True):
    """Function to define the UNET Model"""
    # Contracting Path
    c1 = conv2d_block(input_img, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    p1 = MaxPooling2D((2, 2))(c1)
    p1 = Dropout(dropout)(p1)
    
    c2 = conv2d_block(p1, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    p2 = MaxPooling2D((2, 2))(c2)
    p2 = Dropout(dropout)(p2)
    
    c3 = conv2d_block(p2, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    p3 = MaxPooling2D((2, 2))(c3)
    p3 = Dropout(dropout)(p3)
    
    c4 = conv2d_block(p3, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    p4 = MaxPooling2D((2, 2))(c4)
    p4 = Dropout(dropout)(p4)
    
    c5 = conv2d_block(p4, n_filters = n_filters * 16, kernel_size = 3, batchnorm = batchnorm)
    
    # Expansive Path
    u6 = Conv2DTranspose(n_filters * 8, (3, 3), strides = (2, 2), padding = 'same')(c5)
    u6 = concatenate([u6, c4])
    u6 = Dropout(dropout)(u6)
    c6 = conv2d_block(u6, n_filters * 8, kernel_size = 3, batchnorm = batchnorm)
    
    u7 = Conv2DTranspose(n_filters * 4, (3, 3), strides = (2, 2), padding = 'same')(c6)
    u7 = concatenate([u7, c3])
    u7 = Dropout(dropout)(u7)
    c7 = conv2d_block(u7, n_filters * 4, kernel_size = 3, batchnorm = batchnorm)
    
    u8 = Conv2DTranspose(n_filters * 2, (3, 3), strides = (2, 2), padding = 'same')(c7)
    u8 = concatenate([u8, c2])
    u8 = Dropout(dropout)(u8)
    c8 = conv2d_block(u8, n_filters * 2, kernel_size = 3, batchnorm = batchnorm)
    
    u9 = Conv2DTranspose(n_filters * 1, (3, 3), strides = (2, 2), padding = 'same')(c8)
    u9 = concatenate([u9, c1])
    u9 = Dropout(dropout)(u9)
    c9 = conv2d_block(u9, n_filters * 1, kernel_size = 3, batchnorm = batchnorm)
    
    outputs = Conv2D(1, (1, 1), activation='sigmoid')(c9)
    model = Model(inputs=[input_img], outputs=[outputs])
    return model

# %%
del model_1
input_img = Input((128, 128, 1), name='img')
model_1 = get_unet1(input_img, n_filters=16, dropout=0.12, batchnorm=False)
model_1.compile(optimizer=optimizers.Adam(), loss="binary_crossentropy", metrics=[iou_metric])


callbacks = [
    EarlyStopping(patience=10, verbose=1),
    ReduceLROnPlateau(factor=0.1, patience=5, min_lr=0.00001, verbose=1),
    ModelCheckpoint('model-seg_iou_5.h5', verbose=1, save_best_only=True, save_weights_only=True)
]

results = model_1.fit(X_train, y_train, batch_size=64, epochs=50, callbacks=callbacks,\
                    validation_data=(X_test, y_test))
# Out:
# Train on 360 samples, validate on 90 samples
# Epoch 1/50
# 360/360 [==============================] - 75s 207ms/step - loss: 0.4713 - iou_metric: 0.7133 - val_loss: 0.3487 - val_iou_metric: 0.7353
#
# Epoch 00001: val_loss improved from inf to 0.34872, saving model to model-seg_iou_5.h5
# Epoch 2/50
# 360/360 [==============================] - 71s 198ms/step - loss: 0.3164 - iou_metric: 0.7869 - val_loss: 0.2814 - val_iou_metric: 0.8411
#
# Epoch 00002: val_loss improved from 0.34872 to 0.28142, saving model to model-seg_iou_5.h5
# Epoch 3/50
# 360/360 [==============================] - 82s 228ms/step - loss: 0.3003 - iou_metric: 0.8635 - val_loss: 0.2791 - val_iou_metric: 0.8462
#
# Epoch 00003: val_loss improved from 0.28142 to 0.27912, saving model to model-seg_iou_5.h5
# Epoch 4/50
# 360/360 [==============================] - 78s 216ms/step - loss: 0.2906 - iou_metric: 0.8461 - val_loss: 0.2826 - val_iou_metric: 0.8232
#
# Epoch 00004: val_loss did not improve from 0.27912
# Epoch 5/50
# 360/360 [==============================] - 75s 208ms/step - loss: 0.2836 - iou_metric: 0.8460 - val_loss: 0.2678 - val_iou_metric: 0.8378
#
# Epoch 00005: val_loss improved from 0.27912 to 0.26782, saving model to model-seg_iou_5.h5
# Epoch 6/50
# 360/360 [==============================] - 77s 215ms/step - loss: 0.2767 - iou_metric: 0.8535 - val_loss: 0.2731 - val_iou_metric: 0.8196
#
# Epoch 00006: val_loss did not improve from 0.26782
# Epoch 7/50
# 360/360 [==============================] - 71s 196ms/step - loss: 0.2719 - iou_metric: 0.8557 - val_loss: 0.2863 - val_iou_metric: 0.7996
#
# Epoch 00007: val_loss did not improve from 0.26782
# Epoch 8/50
# 360/360 [==============================] - 71s 196ms/step - loss: 0.2716 - iou_metric: 0.8482 - val_loss: 0.2516 - val_iou_metric: 0.8503
#
# Epoch 00008: val_loss improved from 0.26782 to 0.25165, saving model to model-seg_iou_5.h5
# Epoch 9/50
# 360/360 [==============================] - 72s 199ms/step - loss: 0.2660 - iou_metric: 0.8637 - val_loss: 0.2639 - val_iou_metric: 0.8263
#
# Epoch 00009: val_loss did not improve from 0.25165
# Epoch 10/50
# 360/360 [==============================] - 72s 199ms/step - loss: 0.2611 - iou_metric: 0.8629 - val_loss: 0.2560 - val_iou_metric: 0.8351
#
# Epoch 00010: val_loss did not improve from 0.25165
# Epoch 11/50
# 360/360 [==============================] - 72s 200ms/step - loss: 0.2619 - iou_metric: 0.8582 - val_loss: 0.2497 - val_iou_metric: 0.8431
#
# Epoch 00011: val_loss improved from 0.25165 to 0.24972, saving model to model-seg_iou_5.h5
# Epoch 12/50
# 360/360 [==============================] - 71s 198ms/step - loss: 0.2619 - iou_metric: 0.8571 - val_loss: 0.2574 - val_iou_metric: 0.8313
#
# Epoch 00012: val_loss did not improve from 0.24972
# Epoch 13/50
# 360/360 [==============================] - 72s 200ms/step - loss: 0.2576 - iou_metric: 0.8709 - val_loss: 0.2539 - val_iou_metric: 0.8356
#
# Epoch 00013: val_loss did not improve from 0.24972
# Epoch 14/50
# 360/360 [==============================] - 76s 211ms/step - loss: 0.2552 - iou_metric: 0.8678 - val_loss: 0.2518 - val_iou_metric: 0.8370
#
# Epoch 00014: val_loss did not improve from 0.24972
# Epoch 15/50
# 360/360 [==============================] - 79s 220ms/step - loss: 0.2538 - iou_metric: 0.8654 - val_loss: 0.2510 - val_iou_metric: 0.8370
#
# Epoch 00015: val_loss did not improve from 0.24972
# Epoch 16/50
# 360/360 [==============================] - 76s 211ms/step - loss: 0.2536 - iou_metric: 0.8657 - val_loss: 0.2404 - val_iou_metric: 0.8561
#
# Epoch 00016: val_loss improved from 0.24972 to 0.24037, saving model to model-seg_iou_5.h5
# Epoch 17/50
# 360/360 [==============================] - 75s 207ms/step - loss: 0.2528 - iou_metric: 0.8634 - val_loss: 0.2426 - val_iou_metric: 0.8511
#
# Epoch 00017: val_loss did not improve from 0.24037
# Epoch 18/50
# 360/360 [==============================] - 71s 197ms/step - loss: 0.2527 - iou_metric: 0.8687 - val_loss: 0.2478 - val_iou_metric: 0.8416
#
# Epoch 00018: val_loss did not improve from 0.24037
# Epoch 19/50
# 360/360 [==============================] - 73s 202ms/step - loss: 0.2507 - iou_metric: 0.8738 - val_loss: 0.2487 - val_iou_metric: 0.8395
#
# Epoch 00019: val_loss did not improve from 0.24037
# Epoch 20/50
# 360/360 [==============================] - 79s 220ms/step - loss: 0.2510 - iou_metric: 0.8600 - val_loss: 0.2347 - val_iou_metric: 0.8751
#
# Epoch 00020: val_loss improved from 0.24037 to 0.23471, saving model to model-seg_iou_5.h5
# Epoch 21/50
# 360/360 [==============================] - 72s 200ms/step - loss: 0.2540 - iou_metric: 0.8608 - val_loss: 0.2448 - val_iou_metric: 0.8449
#
# Epoch 00021: val_loss did not improve from 0.23471
# Epoch 22/50
# 360/360 [==============================] - 70s 196ms/step - loss: 0.2525 - iou_metric: 0.8760 - val_loss: 0.2488 - val_iou_metric: 0.8379
#
# Epoch 00022: val_loss did not improve from 0.23471
# Epoch 23/50
# 360/360 [==============================] - 70s 196ms/step - loss: 0.2515 - iou_metric: 0.8594 - val_loss: 0.2339 - val_iou_metric: 0.8677
#
# Epoch 00023: val_loss improved from 0.23471 to 0.23387, saving model to model-seg_iou_5.h5
# Epoch 24/50
# 360/360 [==============================] - 72s 201ms/step - loss: 0.2516 - iou_metric: 0.8743 - val_loss: 0.2417 - val_iou_metric: 0.8486
#
# Epoch 00024: val_loss did not improve from 0.23387
# Epoch 25/50
# 360/360 [==============================] - 68s 190ms/step - loss: 0.2490 - iou_metric: 0.8691 - val_loss: 0.2375 - val_iou_metric: 0.8569
#
# Epoch 00025: val_loss did not improve from 0.23387
# Epoch 26/50
# 360/360 [==============================] - 69s 191ms/step - loss: 0.2485 - iou_metric: 0.8686 - val_loss: 0.2321 - val_iou_metric: 0.8691
#
# Epoch 00026: val_loss improved from 0.23387 to 0.23208, saving model to model-seg_iou_5.h5
# Epoch 27/50
# 360/360 [==============================] - 69s 191ms/step - loss: 0.2508 - iou_metric: 0.8652 - val_loss: 0.2309 - val_iou_metric: 0.8746
#
# Epoch 00027: val_loss improved from 0.23208 to 0.23086, saving model to model-seg_iou_5.h5
# Epoch 28/50
# 360/360 [==============================] - 68s 189ms/step - loss: 0.2518 - iou_metric: 0.8652 - val_loss: 0.2356 - val_iou_metric: 0.8616
#
# Epoch 00028: val_loss did not improve from 0.23086
# Epoch 29/50
# 360/360 [==============================] - 68s 188ms/step - loss: 0.2502 - iou_metric: 0.8819 - val_loss: 0.2566 - val_iou_metric: 0.8247
#
# Epoch 00029: val_loss did not improve from 0.23086
# Epoch 30/50
# 360/360 [==============================] - 68s 190ms/step - loss: 0.2553 - iou_metric: 0.8451 - val_loss: 0.2322 - val_iou_metric: 0.8771
#
# Epoch 00030: val_loss did not improve from 0.23086
# Epoch 31/50
# 360/360 [==============================] - 68s 189ms/step - loss: 0.2504 - iou_metric: 0.8815 - val_loss: 0.2383 - val_iou_metric: 0.8580
#
# Epoch 00031: val_loss did not improve from 0.23086
# Epoch 32/50
# 360/360 [==============================] - 70s 195ms/step - loss: 0.2483 - iou_metric: 0.8673 - val_loss: 0.2347 - val_iou_metric: 0.8648
#
# Epoch 00032: ReduceLROnPlateau reducing learning rate to 0.00010000000474974513.
#
# Epoch 00032: val_loss did not improve from 0.23086
# Epoch 33/50
# 360/360 [==============================] - 71s 198ms/step - loss: 0.2463 - iou_metric: 0.8758 - val_loss: 0.2348 - val_iou_metric: 0.8640
#
# Epoch 00033: val_loss did not improve from 0.23086
# Epoch 34/50
# 360/360 [==============================] - 71s 198ms/step - loss: 0.2464 - iou_metric: 0.8742 - val_loss: 0.2357 - val_iou_metric: 0.8613
#
# Epoch 00034: val_loss did not improve from 0.23086
# Epoch 35/50
# 360/360 [==============================] - 73s 204ms/step - loss: 0.2465 - iou_metric: 0.8712 - val_loss: 0.2364 - val_iou_metric: 0.8595
#
# Epoch 00035: val_loss did not improve from 0.23086
# Epoch 36/50
# 360/360 [==============================] - 73s 204ms/step - loss: 0.2462 - iou_metric: 0.8709 - val_loss: 0.2355 - val_iou_metric: 0.8614
#
# Epoch 00036: val_loss did not improve from 0.23086
# Epoch 37/50
# 360/360 [==============================] - 71s 197ms/step - loss: 0.2461 - iou_metric: 0.8722 - val_loss: 0.2352 - val_iou_metric: 0.8622
#
# Epoch 00037: ReduceLROnPlateau reducing learning rate to 1.0000000474974514e-05.
#
# Epoch 00037: val_loss did not improve from 0.23086
# Epoch 00037: early stopping

# %%
score = model_1.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test iou:', score[1])
# Out:
# Test loss: 0.23515027629004584
# Test iou: 0.8622392747137282

# %%
plt.figure(figsize=(5,5))
plt.title("Learning curve")
plt.plot(results.history["loss"], label="loss")
plt.plot(results.history["val_loss"], label="val_loss")
plt.plot( np.argmin(results.history["val_loss"]), np.min(results.history["val_loss"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("log_loss")
plt.legend();

plt.figure(figsize=(5,5))
plt.title("Learning curve")
plt.plot(results.history["iou_metric"], label="iou_metric")
plt.plot(results.history["val_iou_metric"], label="val_iou_metric")
plt.plot( np.argmin(results.history["val_iou_metric"]), np.min(results.history["val_iou_metric"]), marker="x", color="r", label="best model")
plt.xlabel("Epochs")
plt.ylabel("IOU")
plt.legend();

# %%
# load the best model
model_1.load_weights('model-seg_iou_5.h5')
# Evaluate on validation set (this must be equals to the best log_loss)
model_1.evaluate(X_test, y_test, verbose=1)
# Out:
# 90/90 [==============================] - 5s 53ms/step
# [0.2308582478099399, 0.8746103591389126]

# %%
# Predict on train, val and test
preds_train_1 = model_1.predict(X_train, verbose=1)
preds_val_1 = model_1.predict(X_test, verbose=1)

preds_train_t_1 = (preds_train_1 > 0.5).astype(np.uint8)
preds_val_t_1 = (preds_val_1 > 0.5).astype(np.uint8)
# Out:
# 360/360 [==============================] - 21s 57ms/step
# 90/90 [==============================] - 5s 53ms/step

# %%
plt.imshow(preds_val_1[13].squeeze())
